# %%
import os
import imp
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import cvxpy as cp

from utils import spectral_analysis
from measurements import constrained_linear_measurement_operator
import matrix_sensitivities as mat_sens

# %% [markdown]
# ## Data Management

# %%
def make_sens_ts(dvdp,dvdq,n=274):
    """Make timeseries of sensitivity matrices"""
    assert dvdp.shape[0] == dvdq.shape[0]
    m_tot = dvdp.shape[0] #total measurments
    m = int(m_tot/n) #Timeseries interval
    svp,svq = [],[] #timeseries list of svp and svq matrices
    for t in range(m):
        svp.append(dvdp[t*n:(t+1)*n,:])
        svq.append(dvdq[t*n:(t+1)*n,:])
    return {'svp':svp,
            'svq':svq}

def make_deviations(data):
    """Make finite differences"""
    p,q,v = data
    (dp,dq,dv) = [np.diff(x) for x in (p,q,v)]
    dx = np.vstack((dp,dq))
    return (dx,dv)

def make_S_tilde(svp,svq):
    """Make wide S_tilde matrix"""
    return np.vstack((svp.T,svq.T)).T

def make_S_0(S_tilde,pct_obs):
    """Make initial observed matrix"""
    O,_ = constrained_linear_measurement_operator(S_tilde,pct_obs)
    O,S_0 = np.asarray(O),np.multiply(np.asarray(O),S_tilde)
    return O,S_0

# %% [markdown]
# # Modeling Complex Power Injections in the IEEE 123-Bus Case using Voltage Sensitivities
#
# ## 1. Hourly Varying Demand, Fixed Power Factor
# A constant power factor of $\alpha_i = 0.9, i = 1,\dots,n$ is applied to all loads.

# %%
path = "/home/sam/github/PowerSensitivities.jl/data/ieee123_ts/HourlyDemand_DB_fixedPF/"
os.chdir(path)
files = "dvdp.pkl","dvdq.pkl",'Pnet.pkl','Qnet.pkl','Volts.pkl'
dvdp,dvdq,p,q,v = [pd.read_pickle(f).values for f in files]
sens = make_sens_ts(dvdp,dvdq)
data = make_deviations((p,q,v))
(dx,dv) = data
svp,svq = sens['svp'],sens['svq']
print(svp[0].shape,svq[0].shape,dx.shape,dv.shape)
# Out:
# (274, 274) (274, 274) (548, 23) (274, 23)

# %%
pct_obs = 0.25
S_tilde = make_S_tilde(svp[0],svq[0])
O,S_0 = make_S_0(S_tilde,pct_obs)

# %%
print("Relative pct. error of the 'true' sensitivity matrix: ",np.linalg.norm(dv[:,0] - S_tilde@dx[:,0])/np.linalg.norm(dv[:,0])*100)
# Out:
# Relative pct. error of the 'true' sensitivity matrix:  1.1973718447073551

# %%
grid_kws = {"height_ratios": (.9, .05), "hspace": .1}
fig,(ax,cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(3.5,3.5/1.61828),constrained_layout=True)
cmap = sns.diverging_palette(250, 30, l=65, center="dark", as_cmap=True)
ax = sns.heatmap(np.asarray(S_0),cmap=cmap,
            center=0,square=True,mask=(np.asarray(S_0)==0),
            xticklabels=False,yticklabels=False,ax=ax,
            cbar_ax=cbar_ax,linewidths=1e-6,
            cbar_kws={"orientation": "horizontal",
                     "label":"Voltage Sensitivity",
                     "pad":0.1},
            rasterized=True)
ax.set_title("{pct_obs:.0f}% Observable Sensitivty Matrix (IEEE 123-bus)".format(pct_obs=pct_obs*100))
# Out:
# Text(0.5, 1.0, '25% Observable Sensitivty Matrix (IEEE 123-bus)')

# %%
known_value_indices = tuple(zip(*[[0, 0], [0, 2], [1, 1], [2, 0], [2, 1]]))
known_values = [1.0, 1.9, 0.8, 3.2, 5.9]
X = np.zeros(shape=(3,3))

# %%
#Setup parameters
imp.reload(mat_sens)
lamb_,delta_ = cp.Parameter(nonneg=True),cp.Parameter(nonneg=True)
lamb_.value,delta_.value = 1.25e-4,6e-3

#Solve problem
S_hat,prob = mat_sens.mat_rec_solution(S_0,dx,dv,lamb=lamb_,o=O,delta=delta_)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.2.0
# ===============================================================================
# (CVXPY) Apr 05 10:45:56 AM: Your problem has 150152 variables, 1 constraints, and 2 parameters.
# (CVXPY) Apr 05 10:45:56 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Apr 05 10:45:56 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Apr 05 10:45:56 AM: Compiling problem (target solver=DIFFCP).
# (CVXPY) Apr 05 10:45:56 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> DIFFCP
# (CVXPY) Apr 05 10:45:56 AM: Applying reduction Dcp2Cone
# (CVXPY) Apr 05 10:45:57 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Apr 05 10:45:57 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Apr 05 10:45:58 AM: Applying reduction DIFFCP
# (CVXPY) Apr 05 10:45:59 AM: Finished problem compilation (took 2.278e+00 seconds).
# (CVXPY) Apr 05 10:45:59 AM: (Subsequent compilations of this problem, using the same arguments, should take less time.)
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Apr 05 10:45:59 AM: Invoking solver DIFFCP  to obtain a solution.
# ------------------------------------------------------------------
# 	       SCS v3.2.0 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 338255, constraints m: 382226
# cones: 	  l: linear vars: 1
# 	  q: soc vars: 43972, qsize: 2
# 	  s: psd vars: 338253, ssize: 1
# settings: eps_abs: 1.0e-05, eps_rel: 1.0e-05, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct
# 	  nnz(A): 1541665, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 7.50e+02  1.00e+00  7.50e+02 -3.74e+02  1.00e-01  3.12e-01
#    250| 1.41e-02  2.97e-04  1.75e-03  1.19e-03  3.21e-01  1.10e+02
#    500| 1.31e-03  6.95e-05  2.35e-03  2.05e-04  3.21e-01  2.30e+02
#    750| 4.13e-02  1.80e-03  1.42e-03  3.46e-03  3.21e-01  3.45e+02
#   1000| 2.85e-04  4.17e-05  1.08e-03  9.30e-04  3.21e-01  4.63e+02
#   1250| 2.14e-04  3.87e-05  8.14e-04  1.05e-03  3.21e-01  5.81e+02
#   1500| 1.91e-04  3.54e-05  7.25e-04  1.06e-03  3.21e-01  6.95e+02
#   1750| 1.66e-04  3.20e-05  6.28e-04  1.08e-03  3.21e-01  8.18e+02
#   2000| 1.28e-04  2.73e-05  4.84e-04  1.15e-03  3.21e-01  9.39e+02
#   2250| 8.57e-05  2.29e-05  3.25e-04  1.24e-03  3.21e-01  1.07e+03
#   2500| 7.05e-05  2.02e-05  2.68e-04  1.27e-03  3.21e-01  1.20e+03
#   2750| 5.92e-05  1.80e-05  2.25e-04  1.28e-03  3.21e-01  1.32e+03
#   3000| 4.93e-05  1.65e-05  1.87e-04  1.30e-03  3.21e-01  1.44e+03
#   3250| 4.05e-05  1.50e-05  1.54e-04  1.31e-03  3.21e-01  1.58e+03
#   3500| 3.94e-03  1.25e-03  2.52e-06  1.39e-03  3.21e-01  1.70e+03
#   3750| 2.47e-05  1.14e-05  9.37e-05  1.33e-03  3.21e-01  1.83e+03
#   4000| 1.74e-05  8.88e-06  6.60e-05  1.35e-03  3.21e-01  1.96e+03
#   4250| 1.13e-05  5.81e-06  4.30e-05  1.36e-03  3.21e-01  2.09e+03
#   4500| 7.68e-06  3.77e-06  2.92e-05  1.37e-03  3.21e-01  2.22e+03
#   4750| 5.72e-06  2.53e-06  2.17e-05  1.38e-03  3.21e-01  2.35e+03
#   5000| 4.56e-06  2.03e-06  1.73e-05  1.38e-03  3.21e-01  2.47e+03
#   5250| 3.79e-06  1.65e-06  1.44e-05  1.38e-03  3.21e-01  2.60e+03
#   5500| 3.23e-06  1.35e-06  1.23e-05  1.38e-03  3.21e-01  2.73e+03
#   5750| 2.80e-06  1.13e-06  1.06e-05  1.38e-03  3.21e-01  2.86e+03
#   5875| 2.61e-06  1.10e-06  9.92e-06  1.38e-03  3.21e-01  2.92e+03
# ------------------------------------------------------------------
# status:  solved
# timings: total: 2.92e+03s = setup: 9.43e-01s + solve: 2.92e+03s
# 	 lin-sys: 8.88e+01s, cones: 2.78e+03s, accel: 7.19e+00s
# ------------------------------------------------------------------
# objective = 0.001383
# ------------------------------------------------------------------
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Apr 05 11:34:43 AM: Problem status: optimal
# (CVXPY) Apr 05 11:34:43 AM: Optimal value: 1.388e-03
# (CVXPY) Apr 05 11:34:43 AM: Compilation took 2.278e+00 seconds
# (CVXPY) Apr 05 11:34:43 AM: Solver (including time spent in interface) took 2.925e+03 seconds

# %%
prob.derivative()

# %%
sns.heatmap(S_0[:100,:100])
plt.figure()
sns.heatmap(S_hat[:100,:100])
plt.figure()
sns.heatmap(S_tilde[:100,:100])
# Out:
# <AxesSubplot:>

# %%
#rel_err_ts = [calc_rel_err(S_hat,make_S_tilde(svp_t,svq_t))*100 for svp_t,svq_t in zip(svp,svq)]

# %%
import utils
rel_err = []
for t,(dv_t,dx_t) in enumerate(zip(dv.T,dx.T)):
    hat_dv_t = S_hat@dx_t
    rel_err.append(utils.calc_vector_rel_err(v_est=hat_dv_t,v_true=dv_t)*100)
plt.plot(rel_err)

# %%
grid_kws = {"height_ratios": (.9, .05), "hspace": .1}
fig,(ax,cbar_ax) = plt.subplots(2, gridspec_kw=grid_kws, figsize=(3.5,3.5/1.61828),constrained_layout=True)
cmap = sns.diverging_palette(250, 30, l=65, center="dark", as_cmap=True)
ax = sns.heatmap(np.asarray(S_hat),cmap=cmap,
            center=0,square=True,mask=(np.asarray(S_hat)==0),
            xticklabels=False,yticklabels=False,ax=ax,
            cbar_ax=cbar_ax,linewidths=1e-6,
            cbar_kws={"orientation": "horizontal",
                     "label":"Voltage Sensitivity",
                     "pad":0.1},
            rasterized=True)

# %% [markdown]
# ### Plot the Spectral Analysis for the IEEE 123 Test Feeder

# %%
cum_sigma,normed_sigma = spectral_analysis(S_tilde)

# %%
plt.plot(cum_sigma)
plt.plot(normed_sigma)
plt.grid()

# %% [markdown]
# ## 2. Synthetic demands, fixed power factor

# %%
path = "/home/sam/github/PowerSensitivities.jl/data/ieee123_ts/Synthetic_DB_fixedPF/"
os.chdir(path)
files = "dvdp.pkl","dvdq.pkl",'Pnet.pkl','Qnet.pkl','Volts.pkl'
dvdp,dvdq,p,q,v = [pd.read_pickle(f).values for f in files]
svp,svq = make_sens_ts(dvdp,dvdq)

# %% [markdown]
# ## 3. Synthetic demands, varying power factor

# %%
path = "/home/sam/github/PowerSensitivities.jl/data/ieee123_ts/Synthetic_DB/"
os.chdir(path)
files = "dvdp.pkl","dvdq.pkl",'Pnet.pkl','Qnet.pkl','Volts.pkl'
dvdp,dvdq,p,q,v = [pd.read_pickle(f).values for f in files]
svp,svq = make_sens_ts(dvdp,dvdq)
