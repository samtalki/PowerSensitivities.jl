# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # This is an example
#
# - In this notebook I am plotting
#
# $$
# y(x) = sin(x)
# $$

# %%
x = np.linspace(-10,10)
plt.plot(np.sin(x))
